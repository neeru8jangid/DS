# %%
import pandas as pd

# %%
df = pd.read_csv('placement.csv')
df
# Out:
#      Gender                         Stream  Internships  CGPA  \
# 0      Male  Electronics And Communication            1     8
# 1    Female               Computer Science            0     7
# 2    Female               Computer Science            1     6
# 3      Male               Computer Science            0     8
# 4      Male                     Mechanical            0     8
# ..      ...                            ...          ...   ...
# 144    Male               Computer Science            2     5
# 145    Male                          Civil            0     7
# 146    Male               Computer Science            1     6
# 147    Male                     Mechanical            0     5
# 148    Male                     Electrical            0     6
#
#      HistoryOfBacklogs  PlacedOrNot  certificates
# 0                    1            1             2
# 1                    1            1             2
# 2                    0            1             3
# 3                    1            1             1
# 4                    0            1             1
# ..                 ...          ...           ...
# 144                  0            1             4
# 145                  0            1             3
# 146                  0            1             3
# 147                  1            0             1
# 148                  0            0             0
#
# [149 rows x 7 columns]

# %%
df['Stream'].value_counts()
# Out:
# Stream
# Computer Science                 78
# Electronics And Communication    19
# Mechanical                       19
# Electrical                       19
# Civil                            14
# Name: count, dtype: int64

# %%
df['Stream'] = df['Stream'].map({'Computer Science':1,'Electronics And Communication':2,'Mechanical':3,'Electrical':4,'Civil':5})
df
# Out:
#      Gender  Stream  Internships  CGPA  HistoryOfBacklogs  PlacedOrNot  \
# 0      Male       2            1     8                  1            1
# 1    Female       1            0     7                  1            1
# 2    Female       1            1     6                  0            1
# 3      Male       1            0     8                  1            1
# 4      Male       3            0     8                  0            1
# ..      ...     ...          ...   ...                ...          ...
# 144    Male       1            2     5                  0            1
# 145    Male       5            0     7                  0            1
# 146    Male       1            1     6                  0            1
# 147    Male       3            0     5                  1            0
# 148    Male       4            0     6                  0            0
#
#      certificates
# 0               2
# 1               2
# 2               3
# 3               1
# 4               1
# ..            ...
# 144             4
# 145             3
# 146             3
# 147             1
# 148             0
#
# [149 rows x 7 columns]

# %%
df['Gender'] = df['Gender'].map({'Female':0,'Male':1})

# %%
x = df.drop('PlacedOrNot',axis=1)
y =df['PlacedOrNot']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn import svm

# %%
model = svm.SVC()

# %%
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8666666666666667
#               precision    recall  f1-score   support
#
#            0       1.00      0.60      0.75        10
#            1       0.83      1.00      0.91        20
#
#     accuracy                           0.87        30
#    macro avg       0.92      0.80      0.83        30
# weighted avg       0.89      0.87      0.86        30

# %%
import joblib
joblib.dump(model, 'model.pkl')
# Out:
# ['model.pkl']
